# %% [markdown]
# ## Superposition

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip3 install qiskit
# Out:
# Requirement already satisfied: qiskit in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (2.5.1)
# Requirement already satisfied: numpy<3,>=2.0 in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (from qiskit) (2.5.1)
# Requirement already satisfied: scipy>=1.14 in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (from qiskit) (1.18.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (from qiskit) (0.18.1)
# Requirement already satisfied: dill>=0.3 in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (from qiskit) (5.9.0)
# Requirement already satisfied: typing-extensions in /Users/hs04/Desktop/Quantum Program/.venv/lib/python3.14/site-packages (from qiskit) (4.16.0)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
print(circuit)
# Out:
#      ┌───┐┌─┐
# q_0: ┤ H ├┤M├
#      └───┘└╥┘
# q_1: ──────╫─
#            ║
# q_2: ──────╫─
#            ║
# q_3: ──────╫─
#            ║
# c: 4/══════╩═
#            0

# %% [markdown]
# ## Entaglement
#
# ![image.png](attachment:image.png)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
print(circuit)
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# q_2: ───────────╫──╫─
#                 ║  ║
# q_3: ───────────╫──╫─
#                 ║  ║
# c: 4/═══════════╩══╩═
#                 0  1

# %% [markdown]
# ## Deutch Josza Algorithm
#
# ### 1) Contstant System
#
# ![image.png](attachment:image.png)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
print(circuit)
# Out:
#      ┌───┐     ┌───┐┌─┐
# q_0: ┤ H ├──■──┤ H ├┤M├
#      ├───┤┌─┴─┐└───┘└╥┘
# q_1: ┤ H ├┤ X ├──────╫─
#      └───┘└───┘      ║
# q_2: ────────────────╫─
#                      ║
# q_3: ────────────────╫─
#                      ║
# c: 4/════════════════╩═
#                      0

# %% [markdown]
# ### Balanced system
# ![image.png](attachment:image.png)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.x(qreg_q[1])
circuit.h(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
print(circuit)
# Out:
#      ┌───┐          ┌───┐┌─┐
# q_0: ┤ H ├───────■──┤ H ├┤M├
#      ├───┤┌───┐┌─┴─┐└───┘└╥┘
# q_1: ┤ X ├┤ H ├┤ X ├──────╫─
#      └───┘└───┘└───┘      ║
# q_2: ─────────────────────╫─
#                           ║
# q_3: ─────────────────────╫─
#                           ║
# c: 4/═════════════════════╩═
#                           0
