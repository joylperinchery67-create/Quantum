# %% [markdown]
# ## whats one thing he said that connects to something youve already lived through - not in a classroom, in your actual life?
#
# ### in the unstable smp the null faction uses quantum entangled totem of undying that made me understand what quantum entanglment was
#
# ## have you ever been two diffrent things at once - depending on who was watching? what does superposition say about that
#
# ### i sometimes behave diffrently at diffrent times such as superposition
#
# ## Think of a desicion you made where you couldnt know the outcome untill you commited to it.How is that like measurement collapsing a quibit
#
# ### i could not know the outcome of my test results until i did commited to it and found my score later
